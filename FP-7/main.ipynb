# %% [markdown]
# # Final Project FP-3:  Descriptive Statistics
#
#
# <br>
# <br>

# %% [markdown]
# ___
#
# <br>
#
# # Analysis of factors contributing to red wine quality
#
#
# * **Name**: Mingdong Gao
# * **Student number**:  0900369856
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The purpose of this study is to determine which factors of music therapy contribute most to improvements in people's mental health.
# * Key DVs include:
#   * the ranks of Anxiety
#   * Depression
#   * Insomnia
#   * OCD
# * All DVs above are being rated on a scale of 0 to 10.
# * Key IVs include:
#   * music genre
#   * age
#   * gender
#   * frequency
#   * frequency of listening to different genres
#   * place
#   * BPM of the music
#   * duration
#   * main streaming platform
#   * Instrumentalist (Does the participant play an instrument)
# * There are 4 DVs and 29 IVs, the number of cases is over 700
#
#
# <br>

# %% [markdown]
# ### Dataset source:
#
# * The data is being collected through an open Google form; the region and age of the participants are not being restricted.
# * The hard questions (e.g., the BPM of the music) is not compulsory.
# * The data is being organized by Catherine Rasgaitis, from the University of Washington
# * The dataset can be downloaded [here](https://www.kaggle.com/datasets/catherinerasgaitis/mxmh-survey-results/data?select=mxmh_survey_results.csv)

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %%
# %%capture
# %run descriptive.ipynb

# %%
display_central_tendency_table(num=1)
display_dispersion_table(num=2)
# Out:
# <br><br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary statistics.</span></p>
#         Anxiety     Age  Duration      BPM
# mean      5.866  24.753  3.713462  123.215
# median    6.000  21.000  3.000000  120.000
# mode      7.000  18.000  2.000000  120.000
# <br><br><p><span style="font-size: 1.2em;"><b>Table 2</b>: Dispersion summary statistics.</span></p>
#            Anxiety        Age  Duration         BPM
# st.dev.   2.765422  11.699906   3.08994   32.873232
# min       0.000000  10.000000   0.00000    4.000000
# max      10.000000  89.000000  24.00000  220.000000
# range    10.000000  79.000000  24.00000  216.000000
# 25th      4.000000  18.000000   2.00000  100.000000
# 75th      8.000000  27.000000   5.00000  144.000000
# IQR       4.000000   9.000000   3.00000   44.000000

# %%
plot_descriptive()

# %% [markdown]
# ### Hypothesis testing

# %%
# %%capture
# %run classical.ipynb

# %%
display_ttest_duration_plot()
display_interaction_plots()

# %% [markdown]
# ### Machine Learning

# %%
# %%capture
# %run machine.ipynb

# %%
plot_svm()
validation2()
# Out:
#      Fold Accuracy
# 0  Fold 1    0.426
# 1  Fold 2    0.415
# 2  Fold 3    0.415
# 3  Fold 4    0.441
# 4  Fold 5    0.473
# 5    Mean    0.434
# 6     Std   0.0218

# %% [markdown]
# ### Overall, the machine learning results show that the models have very fair predictive ability. The figure indicates that the model shows acceptable performance in predicting.

# %% [markdown]
# ## Machine Learning Challenge

# %%
# %run machine_learning_challenge.ipynb
# Out:
# Age Group
# 30-39    67
# 50-59    17
# 0-19      0
# 20-29     0
# 40-49     0
# 60-69     0
# 70+       0
# Name: count, dtype: int64
# target
# 0    67
# 1    17
# Name: count, dtype: int64
# Explained variance ratio: [0.39735494 0.27384695]
# Total variance explained: 0.6712018916127878
# Top features by |PC1 loading|:
# Anxiety          0.694009
# Age              0.624207
# Hours per day    0.351499
# BPM              0.071865
# Name: PC1, dtype: float64
# Spearman rho = 0.101, p = 0.0116

# %% [markdown]
# The PCA projection indicates modest separation between the 30–39 and 50–59 age groups, with PC1 largely influenced by Anxiety, Age, and Hours per day. Although a statistically significant correlation is observed between listening hours and anxiety, the effect size is small, suggesting a weak association.
