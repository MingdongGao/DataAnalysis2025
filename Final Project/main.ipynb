# %% [markdown]
# # Final Project : Analysis of how music therapy influences human mental health
#
#
# <br>
# <br>

# %% [markdown]
# ___
#
# <br>
#
#
# * **Name**: Mingdong Gao
# * **Student number**:  0900369856
#
# <br>

# %% [markdown]
# # Overview
#
# ### Purpose:
#
# * The purpose of this study is to determine which factors of music therapy contribute most to improvements in people's mental health.
# * Key DVs include:
#   * the ranks of Anxiety
#   * Depression
#   * Insomnia
#   * Obsessive-compulsive disorder (OCD)
# * All DVs above are being rated on a scale of 0 to 10.
# * Key IVs include:
#   * music genre
#   * age
#   * gender
#   * frequency of listening to music
#   * frequency of listening to different genres
#   * place
#   * BPM of the music
#   * duration
#   * main streaming platform
#   * instrumentalist (does the participant play an instrument)
# * There are 4 DVs and 29 IVs, the number of cases is over 700
#
#
# <br>

# %% [markdown]
# ### Dataset source:
#
# * The data is being collected through an open Google form; the region and age of the participants are not being restricted.
# * The hard questions (e.g., the BPM of the music) is not compulsory.
# * The data is being organized by Catherine Rasgaitis, from the University of Washington
# * The dataset can be downloaded [here](https://www.kaggle.com/datasets/catherinerasgaitis/mxmh-survey-results/data?select=mxmh_survey_results.csv)

# %% [markdown]
# ___
#
# # Descriptive Statistics

# %%
# %%capture
# %run descriptive.ipynb

# %%
descriptive_table(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_89e3e">
#   <caption>Table 1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89e3e_level0_col0" class="col_heading level0 col0" >Anxiety</th>
#       <th id="T_89e3e_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_89e3e_level0_col2" class="col_heading level0 col2" >Duration</th>
#       <th id="T_89e3e_level0_col3" class="col_heading level0 col3" >BPM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89e3e_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_89e3e_row0_col0" class="data row0 col0" >central tendency</td>
#       <td id="T_89e3e_row0_col1" class="data row0 col1" ></td>
#       <td id="T_89e3e_row0_col2" class="data row0 col2" ></td>
#       <td id="T_89e3e_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_89e3e_row1_col0" class="data row1 col0" >5.87</td>
#       <td id="T_89e3e_row1_col1" class="data row1 col1" >24.8</td>
#       <td id="T_89e3e_row1_col2" class="data row1 col2" >3.71</td>
#       <td id="T_89e3e_row1_col3" class="data row1 col3" >123</td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row2" class="row_heading level0 row2" >median</th>
#       <td id="T_89e3e_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_89e3e_row2_col1" class="data row2 col1" >21</td>
#       <td id="T_89e3e_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_89e3e_row2_col3" class="data row2 col3" >120</td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row3" class="row_heading level0 row3" >mode</th>
#       <td id="T_89e3e_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_89e3e_row3_col1" class="data row3 col1" >18</td>
#       <td id="T_89e3e_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_89e3e_row3_col3" class="data row3 col3" >120</td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row4" class="row_heading level0 row4" ></th>
#       <td id="T_89e3e_row4_col0" class="data row4 col0" >dispersion</td>
#       <td id="T_89e3e_row4_col1" class="data row4 col1" ></td>
#       <td id="T_89e3e_row4_col2" class="data row4 col2" ></td>
#       <td id="T_89e3e_row4_col3" class="data row4 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row5" class="row_heading level0 row5" >std</th>
#       <td id="T_89e3e_row5_col0" class="data row5 col0" >2.77</td>
#       <td id="T_89e3e_row5_col1" class="data row5 col1" >11.7</td>
#       <td id="T_89e3e_row5_col2" class="data row5 col2" >3.09</td>
#       <td id="T_89e3e_row5_col3" class="data row5 col3" >32.9</td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row6" class="row_heading level0 row6" >min</th>
#       <td id="T_89e3e_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_89e3e_row6_col1" class="data row6 col1" >10</td>
#       <td id="T_89e3e_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_89e3e_row6_col3" class="data row6 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_89e3e_row7_col0" class="data row7 col0" >10</td>
#       <td id="T_89e3e_row7_col1" class="data row7 col1" >89</td>
#       <td id="T_89e3e_row7_col2" class="data row7 col2" >24</td>
#       <td id="T_89e3e_row7_col3" class="data row7 col3" >220</td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row8" class="row_heading level0 row8" >range</th>
#       <td id="T_89e3e_row8_col0" class="data row8 col0" >10</td>
#       <td id="T_89e3e_row8_col1" class="data row8 col1" >79</td>
#       <td id="T_89e3e_row8_col2" class="data row8 col2" >24</td>
#       <td id="T_89e3e_row8_col3" class="data row8 col3" >216</td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row9" class="row_heading level0 row9" >25th</th>
#       <td id="T_89e3e_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_89e3e_row9_col1" class="data row9 col1" >18</td>
#       <td id="T_89e3e_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_89e3e_row9_col3" class="data row9 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row10" class="row_heading level0 row10" >75th</th>
#       <td id="T_89e3e_row10_col0" class="data row10 col0" >8</td>
#       <td id="T_89e3e_row10_col1" class="data row10 col1" >27</td>
#       <td id="T_89e3e_row10_col2" class="data row10 col2" >5</td>
#       <td id="T_89e3e_row10_col3" class="data row10 col3" >144</td>
#     </tr>
#     <tr>
#       <th id="T_89e3e_level0_row11" class="row_heading level0 row11" >IQR</th>
#       <td id="T_89e3e_row11_col0" class="data row11 col0" >4</td>
#       <td id="T_89e3e_row11_col1" class="data row11 col1" >9</td>
#       <td id="T_89e3e_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_89e3e_row11_col3" class="data row11 col3" >44</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Table 1. Descriptive statistics (central tendency and dispersion)
#
# This table shows the average values and spread of the main variables. Anxiety values are relatively consistent across participants, while Age and BPM vary more widely, indicating greater differences between individuals.

# %%
plot_descriptive()

# %% [markdown]
# ### Figure 1. Relationship between Duration and Anxiety
#
# This figure explores simple linear relationships between anxiety and age, listening duration, and BPM. All correlations are very weak (|r| < 0.2), indicating that none of these variables alone meaningfully explains anxiety levels. This suggests that anxiety is unlikely to be driven by any single music-related factor in a linear way.

# %% [markdown]
# # Hypothesis testing

# %%
# %%capture
# %run classical.ipynb

# %%
display_ttest_duration_plot()

# %% [markdown]
# ### Figure 2. Anxiety by Duration Group (t-test)
#
# Following the linear correlations, listening duration was dichotomized to test for potential group-level differences in anxiety. Although the t-test indicates a statistically significant difference (p = 0.030), the distributions overlap substantially, indicating a small effect size with limited practical relevance. This suggests that duration alone is unlikely to be a meaningful driver of anxiety differences.

# %%
display_interaction_plots()

# %% [markdown]
# ### Figure 3. Interaction Effects of Duration with BPM and Age
#
# Given the limited main effects, interaction analyses were conducted to assess whether BPM or age moderates the relationship between duration and anxiety. While slight trends are visible, wide and overlapping confidence intervals indicate no robust interaction effects. These results further suggest that simple two-way combinations of variables do not explain anxiety well.

# %% [markdown]
# # Machine Learning

# %%
# %%capture
# %run machine.ipynb

# %%
plot_actual_vs_predicted()

# %% [markdown]
# ### Figure 4. Actual vs Predicted Anxiety (Linear Regression)
#
# Based on the above analyses, a multivariable linear regression model was applied to predict anxiety levels. The model largely predicts values near the mean and fails to capture extremes, demonstrating poor predictive performance. This indicates that the data structure is not well suited to linear modeling.

# %%
plot_svm()

# %% [markdown]
# ### Figure 5. Confusion Matrix (SVM Classification)
#
# Given the failure of linear regression, a non-linear SVM classifier was applied to capture potential complex patterns. The model predominantly predicts the medium-anxiety category and poorly distinguishes low and high anxiety levels. This suggests that non-linearity alone does not resolve the underlying predictive limitations.

# %%
validation2()
# Out:
# <style type="text/css">
# </style>
# <table id="T_269c3">
#   <caption>Table 2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_269c3_level0_col0" class="col_heading level0 col0" >Fold</th>
#       <th id="T_269c3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_269c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_269c3_row0_col0" class="data row0 col0" >Fold 1</td>
#       <td id="T_269c3_row0_col1" class="data row0 col1" >0.426</td>
#     </tr>
#     <tr>
#       <th id="T_269c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_269c3_row1_col0" class="data row1 col0" >Fold 2</td>
#       <td id="T_269c3_row1_col1" class="data row1 col1" >0.415</td>
#     </tr>
#     <tr>
#       <th id="T_269c3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_269c3_row2_col0" class="data row2 col0" >Fold 3</td>
#       <td id="T_269c3_row2_col1" class="data row2 col1" >0.415</td>
#     </tr>
#     <tr>
#       <th id="T_269c3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_269c3_row3_col0" class="data row3 col0" >Fold 4</td>
#       <td id="T_269c3_row3_col1" class="data row3 col1" >0.441</td>
#     </tr>
#     <tr>
#       <th id="T_269c3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_269c3_row4_col0" class="data row4 col0" >Fold 5</td>
#       <td id="T_269c3_row4_col1" class="data row4 col1" >0.473</td>
#     </tr>
#     <tr>
#       <th id="T_269c3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_269c3_row5_col0" class="data row5 col0" >Mean</td>
#       <td id="T_269c3_row5_col1" class="data row5 col1" >0.434</td>
#     </tr>
#     <tr>
#       <th id="T_269c3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_269c3_row6_col0" class="data row6 col0" >Std</td>
#       <td id="T_269c3_row6_col1" class="data row6 col1" >0.0218</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Table 2. SVM Cross-Validation Accuracy
#
# Cross-validation accuracy remains low and stable (mean ≈ 0.43), confirming that the SVM model does not generalize well. This indicates that the limitation lies in the dataset rather than the modeling technique.

# %% [markdown]
# # Summary

# %% [markdown]
# Across a sequence of increasingly complex analyses, the results consistently indicate limited explanatory power. Initial descriptive analyses and correlations show only very weak linear relationships between anxiety and music-related variables such as duration, BPM, and age. Group comparisons and interaction analyses identify statistically significant but practically small effects, while multivariable linear regression fails to predict anxiety accurately, indicating that the data structure is not well captured by linear assumptions. Subsequent non-linear modeling using SVM does not meaningfully improve performance, suggesting that the limitation lies in the information content of the dataset rather than the modeling approach.

# %% [markdown]
# ### Recommendation to the Client
# Based on these findings, it is recommended that the client reconsider the reliance on the current database for drawing conclusions about mental health outcomes. Anxiety and related mental health conditions are highly complex and likely to be influenced by factors like clinical, psychological, social, and environmental factors that are not captured in this dataset. The client should either abandon this database in favor of more comprehensive public datasets or collaborate with academic or clinical research teams to access more professional mental health data with validated measures and better variables.
