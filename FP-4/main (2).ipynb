# %%
import pandas as pd
df = pd.read_csv("mxmh survey results2.csv")  

import descriptive as desc
import parse_data as pdata

df = pdata.load_mxmh_data()
central_tbl, disp_tbl = desc.display_summary_table(df)
fig, axes = desc.plot_descriptive(df)
# Out:
# === Central tendency summary statistics ===
#         Anxiety     Age  Duration      BPM
# mean      5.866  24.753     3.713  123.215
# median    6.000  21.000     3.000  120.000
# mode      7.000  18.000     2.000  120.000
#
# === Dispersion summary statistics ===
#        Anxiety     Age  Duration    BPM
# std      2.768  11.709     3.092   32.9
# min      0.000  10.000     0.000    4.0
# max     10.000  89.000    24.000  220.0
# range   10.000  79.000    24.000  216.0
# 25th     4.000  18.000     2.000  100.0
# 75th     8.000  27.000     5.000  144.0
# IQR      4.000   9.000     3.000   44.0
